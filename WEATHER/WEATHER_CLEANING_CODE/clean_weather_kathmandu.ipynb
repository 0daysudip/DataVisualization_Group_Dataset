# %%
import pandas as pd

INPUT  = r"C:\Users\asus\Desktop\New_Dataset\WEATHER\Weather_Kathmandu.csv"
OUTPUT = r"C:\Users\asus\Desktop\New_Dataset\WEATHER\Weather_Kathmandu_Cleaned.csv"

df = pd.read_csv(INPUT)

print("Raw rows     :", len(df))
print("Raw columns  :", df.columns.tolist())
print()
print(df.head(3).to_string())

df["sensor_id"] = 14153357

df["date"] = pd.to_datetime(df["date"]).dt.strftime("%Y-%m-%d")

df = df.rename(columns={
    "rainfall_mm"   : "rainfall (mm)",
    "humidity_pct"  : "humidity (%)",
    "windspeed_kmh" : "windspeed (km/h)",
})

df = df.dropna()

df = df[df["rainfall (mm)"].between(0, 400)]
df = df[df["humidity (%)"].between(0, 100)]
df = df[df["windspeed (km/h)"].between(0, 150)]

df = df[["sensor_id", "date", "rainfall (mm)", "humidity (%)", "windspeed (km/h)"]]

df = df.sort_values("date").reset_index(drop=True)

df.to_csv(OUTPUT, index=False)

print(f"\nCleaned rows : {len(df):,}")
print(f"Columns      : {df.columns.tolist()}")
print(f"Saved to     : {OUTPUT}")
print()
print(df.head(10).to_string())
# Out:
# Raw rows     : 287
# Raw columns  : ['date', 'temp_mean_c', 'temp_max_c', 'temp_min_c', 'rainfall_mm', 'humidity_pct', 'windspeed_kmh', 'city', 'latitude', 'longitude', 'source', 'year', 'month', 'year_month']
#
#          date  temp_mean_c  temp_max_c  temp_min_c  rainfall_mm  humidity_pct  windspeed_kmh       city  latitude  longitude                                              source  year  month year_month
# 0  2025-10-01         21.1        26.3        17.4         11.7            87            7.0  Kathmandu   27.7172     85.324  Open-Meteo Historical Weather API (open-meteo.com)  2025     10    2025-10
# 1  2025-10-02         20.3        22.3        18.6         29.0            92            5.6  Kathmandu   27.7172     85.324  Open-Meteo Historical Weather API (open-meteo.com)  2025     10    2025-10
# 2  2025-10-03         21.1        24.5        18.4          8.6            88            4.9  Kathmandu   27.7172     85.324  Open-Meteo Historical Weather API (open-meteo.com)  2025     10    2025-10
#
# Cleaned rows : 287
# Columns      : ['sensor_id', 'date', 'rainfall (mm)', 'humidity (%)', 'windspeed (km/h)']
# Saved to     : C:\Users\asus\Desktop\New_Dataset\WEATHER\Weather_Kathmandu_Cleaned.csv
#
#    sensor_id        date  rainfall (mm)  humidity (%)  windspeed (km/h)
# 0   14153357  2025-10-01           11.7            87               7.0
# 1   14153357  2025-10-02           29.0            92               5.6
# 2   14153357  2025-10-03            8.6            88               4.9
# 3   14153357  2025-10-04           90.9            98               9.4
# 4   14153357  2025-10-05           10.9            88               7.0
# 5   14153357  2025-10-06            2.8            88               9.3
# 6   14153357  2025-10-07            4.8            89               6.7
# 7   14153357  2025-10-08            3.9            88               8.7
# 8   14153357  2025-10-09            0.0            85              11.0
# 9   14153357  2025-10-10            0.0            76              12.1
