# %%
import pandas as pd

INPUT  = r"C:\Users\asus\Desktop\New_Dataset\WEATHER\Weather_Pokhara.csv"
OUTPUT = r"C:\Users\asus\Desktop\New_Dataset\WEATHER\Weather_Pokhara_Cleaned.csv"

df = pd.read_csv(INPUT)

print("Raw rows     :", len(df))
print("Raw columns  :", df.columns.tolist())
print()
print(df.head(3).to_string())

df["sensor_id"] = 14292737

df["date"] = pd.to_datetime(df["date"]).dt.strftime("%Y-%m-%d")

df = df.rename(columns={
    "rainfall_mm"   : "rainfall (mm)",
    "humidity_pct"  : "humidity (%)",
    "windspeed_kmh" : "windspeed (km/h)",
})

df = df.dropna()

df = df[df["rainfall (mm)"].between(0, 400)]
df = df[df["humidity (%)"].between(0, 100)]
df = df[df["windspeed (km/h)"].between(0, 150)]

df = df[["sensor_id", "date", "rainfall (mm)", "humidity (%)", "windspeed (km/h)"]]

df = df.sort_values("date").reset_index(drop=True)

df.to_csv(OUTPUT, index=False)

print(f"\nCleaned rows : {len(df):,}")
print(f"Columns      : {df.columns.tolist()}")
print(f"Saved to     : {OUTPUT}")
print()
print(df.head(10).to_string())
# Out:
# Raw rows     : 287
# Raw columns  : ['date', 'temp_mean_c', 'temp_max_c', 'temp_min_c', 'rainfall_mm', 'humidity_pct', 'windspeed_kmh', 'city', 'latitude', 'longitude', 'source', 'year', 'month', 'year_month']
#
#          date  temp_mean_c  temp_max_c  temp_min_c  rainfall_mm  humidity_pct  windspeed_kmh     city  latitude  longitude                                              source  year  month year_month
# 0  2025-10-01         23.7        28.4        20.7          0.8            76            4.9  Pokhara   28.2096    83.9856  Open-Meteo Historical Weather API (open-meteo.com)  2025     10    2025-10
# 1  2025-10-02         21.2        24.7        18.9         22.4            88            8.9  Pokhara   28.2096    83.9856  Open-Meteo Historical Weather API (open-meteo.com)  2025     10    2025-10
# 2  2025-10-03         22.5        25.9        19.1          1.5            82            7.8  Pokhara   28.2096    83.9856  Open-Meteo Historical Weather API (open-meteo.com)  2025     10    2025-10
#
# Cleaned rows : 287
# Columns      : ['sensor_id', 'date', 'rainfall (mm)', 'humidity (%)', 'windspeed (km/h)']
# Saved to     : C:\Users\asus\Desktop\New_Dataset\WEATHER\Weather_Pokhara_Cleaned.csv
#
#    sensor_id        date  rainfall (mm)  humidity (%)  windspeed (km/h)
# 0   14292737  2025-10-01            0.8            76               4.9
# 1   14292737  2025-10-02           22.4            88               8.9
# 2   14292737  2025-10-03            1.5            82               7.8
# 3   14292737  2025-10-04           42.3            92              12.6
# 4   14292737  2025-10-05            0.0            86               7.9
# 5   14292737  2025-10-06            0.0            85               6.0
# 6   14292737  2025-10-07            0.0            81               5.2
# 7   14292737  2025-10-08            0.0            82               9.0
# 8   14292737  2025-10-09            0.0            80               6.4
# 9   14292737  2025-10-10            0.0            73               8.8
